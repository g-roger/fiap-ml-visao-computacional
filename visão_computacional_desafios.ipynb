# %% [markdown]
# <a href="https://colab.research.google.com/github/g-roger/fiap-ml-visao-computacional/blob/master/vis%C3%A3o_computacional_desafios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/g-roger/fiap-ml-visao-computacional
# Out:
# Cloning into 'fiap-ml-visao-computacional'...
# remote: Enumerating objects: 11566, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 11566 (delta 58), reused 87 (delta 30), pack-reused 11432
# Receiving objects: 100% (11566/11566), 1004.80 MiB | 27.78 MiB/s, done.
# Resolving deltas: 100% (509/509), done.
# Checking out files: 100% (10577/10577), done.

# %%
# %cd fiap-ml-visao-computacional/aula-1-introducao-visao-computacional/
# Out:
# /content/fiap-ml-visao-computacional/aula-1-introducao-visao-computacional/fiap-ml-visao-computacional/aula-1-introducao-visao-computacional

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2

# Exibição na mesma tela do Jupyter
# %matplotlib inline

plt.style.use("seaborn")
sns.set_style("whitegrid", {"axes.grid" : False})

# %%
imagem = cv2.imread("imagens/russia.jpg", cv2.IMREAD_COLOR)

# %%
imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(20,10))
plt.imshow(imagem)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
